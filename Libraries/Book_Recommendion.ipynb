# %%
import pandas as pd
import numpy as np

# %%
Book_Df=pd.read_csv("../data/CSV_Datasets/BooksDatasetClean.csv")

# %%
# Book_Df.sort_values(by='Price Starting With ($)' ,ascending=False).head()
Book_Df.sort_values(by='Price Starting With ($)' ,ascending=False).head(5)
# Out:
#                                          Title            Authors  \
# 12556  The Girl Who Loved Tom Gordon : A Novel   By King, Stephen
# 60626                       Smoky the Cowhorse     By James, Will
# 28803                             Go Ask Alice  By James Jennings
# 33495     A journey to the centre of the earth     By Jules Verne
# 58592                      A Pair of Blue Eyes    By Thomas Hardy
#
#                                              Description  \
# 12556  From international bestseller Stephen King, a ...
# 60626                                                NaN
# 28803  Based on the diary of a fifteen-year-old drug ...
# 33495                                                NaN
# 58592                                                NaN
#
#                        Category                         Publisher  \
# 12556   Fiction , Psychological                          Scribner
# 60626                       NaN           Charles Scribner's Sons
# ...

# %%
Book_Df.columns
# Out:
# Index(['Title', 'Authors', 'Description', 'Category', 'Publisher',
#        'Price Starting With ($)', 'Publish Date (Month)',
#        'Publish Date (Year)'],
#       dtype='object')
