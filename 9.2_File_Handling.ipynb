# %%
f =open("./data/file.txt","r")
a=f.read()
print(a)
# Out:
# Hello
# my name is pankaj

# %%
data=["hi gagan","how are you","what are you doing"]
with open("./data/file.txt","w") as f:
    for i in data:
        f.writelines(i+"\n")
